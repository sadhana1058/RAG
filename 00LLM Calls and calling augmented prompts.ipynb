# %%
from together import Together

# %%
# !pip3 install together
# Out:
# DEPRECATION: Loading egg at /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dlib-20.0.99-py3.11-macosx-10.9-universal2.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: together in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.5.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (3.11.16)
# Requirement already satisfied: black<26.0.0,>=25.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (25.12.0)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (8.1.8)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (0.2.2)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (3.18.0)
# Requirement already satisfied: numpy>=1.23.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (2.2.4)
# Requirement already satisfied: pillow<12.0.0,>=11.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (11.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (2.32.3)
# Requirement already satisfied: rich<15.0.0,>=13.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (14.0.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (4.67.1)
# Requirement already satisfied: typer<0.20,>=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from together) (0.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.19.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from black<26.0.0,>=25.9.0->together) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from black<26.0.0,>=25.9.0->together) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from black<26.0.0,>=25.9.0->together) (1.0.1)
# Requirement already satisfied: platformdirs>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from black<26.0.0,>=25.9.0->together) (4.3.7)
# Requirement already satisfied: pytokens>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from black<26.0.0,>=25.9.0->together) (0.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.3->together) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.3->together) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.3->together) (4.13.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.3->together) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->together) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->together) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->together) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->together) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich<15.0.0,>=13.8.1->together) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich<15.0.0,>=13.8.1->together) (2.19.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from typer<0.20,>=0.9->together) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.8.1->together) (0.1.2)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
from together import Together
# Out:
# ╭───────────────────────────────────────────── 🚀 New SDK Available ──────────────────────────────────────────────╮
# │ Together Python SDK 2.0 is now available!                                                                       │
# │                                                                                                                 │
# │ Install the beta:                                                                                               │
# │ pip install --pre together  or  uv add together --prerelease allow                                              │
# │                                                                                                                 │
# │ New SDK: ]8;id=330228;https://github.com/togethercomputer/together-py\https://github.com/togethercomputer/together-py]8;;\                                                        │
# │ Migration guide: ]8;id=956109;https://docs.together.ai/docs/pythonv2-migration-guide\https://docs.together.ai/docs/pythonv2-migration-guide]8;;\                                         │
# │                                                                                                                 │
# │ This package will be maintained until January 2026.                                                             │
# │ Set TOGETHER_NO_BANNER=1 to hide this message.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /usr/local/bin/python3.12
# 3.12.7 (v3.12.7:0b05ead877f, Sep 30 2024, 23:18:00) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
from utils import (
    generate_with_single_input, 
    generate_with_multiple_input
)
# Out:
# ╭───────────────────────────────────────────── 🚀 New SDK Available ──────────────────────────────────────────────╮
# │ Together Python SDK 2.0 is now available!                                                                       │
# │                                                                                                                 │
# │ Install the beta:                                                                                               │
# │ pip install --pre together  or  uv add together --prerelease allow                                              │
# │                                                                                                                 │
# │ New SDK: ]8;id=212304;https://github.com/togethercomputer/together-py\https://github.com/togethercomputer/together-py]8;;\                                                        │
# │ Migration guide: ]8;id=260322;https://docs.together.ai/docs/pythonv2-migration-guide\https://docs.together.ai/docs/pythonv2-migration-guide]8;;\                                         │
# │                                                                                                                 │
# │ This package will be maintained until January 2026.                                                             │
# │ Set TOGETHER_NO_BANNER=1 to hide this message.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
output = generate_with_single_input(
    prompt="What is the capital of France?"
)

print("Role:", output['role'])
print("Content:", output['content'])
print(output)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxy.dlai.link'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 output = generate_with_single_input(
#       2     prompt="What is the capital of France?"
#       3 )
#       5 print("Role:", output['role'])
#       6 print("Content:", output['content'])
#
# File ~/Desktop/RAG/utils.py:33, in generate_with_single_input(prompt, role, top_p, temperature, max_tokens, model, together_api_key, **kwargs)
#      31 response = requests.post(url, json = payload, verify=False)
#      32 if not response.ok:
# ---> 33     raise Exception(f"Error while calling LLM: f{response.text}")
#      34 try:
#      35     json_dict = json.loads(response.text)
#
# Exception: Error while calling LLM: f<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <HTML><HEAD><META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=iso-8859-1">
# <TITLE>ERROR: The request could not be satisfied</TITLE>
# </HEAD><BODY>
# <H1>403 ERROR</H1>
# <H2>The request could not be satisfied.</H2>
# <HR noshade size="1px">
# Request blocked.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <BR clear="all">
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <BR clear="all">
# <HR noshade size="1px">
# <PRE>
# Generated by cloudfront (CloudFront)
# Request ID: Khq6-Co12BvKn4kt0-48DeB2GytoIvN273WDKRNSH18L54w5uBbGOA==
# </PRE>
# <ADDRESS>
# </ADDRESS>
# </BODY></HTML>
